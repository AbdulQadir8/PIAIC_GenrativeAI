# %%
from openai import OpenAI
from dotenv import load_dotenv,find_dotenv

_ : bool = load_dotenv("/home/abdul-qadir/PIAIC_GenrativeAI/03_streaming_response/.env") # read local .env file

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

stream = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[{"role":"user","content":"You are a financial adviser, skilled in councelling in financial problems"},
              {"role":"system","content":"Compose a paragraph on investing in mututal funds"}
              ],
    stream=True

)

for part in stream:
    print(part.choices[0].delta.content or "")
# Out:
# When
#  it
#  comes
#  to
#  investing
# ,
#  mutual
#  funds
#  can
#  be
#  an
#  excellent
#  option
#  for
#  many
#  individuals
# .
#  Mutual
#  funds
#  offer
#  divers
# ification
#  by
#  pooling
#  money
#  from
#  multiple
#  investors
#  to
#  buy
#  a
#  portfolio
#  of
#  stocks
# ,
#  bonds
# ,
#  or
#  other
#  securities
# .
#  This
#  divers
# ification
#  can
#  help
#  reduce
#  risk
#  compared
#  to
#  investing
#  in
#  individual
#  stocks
#  or
#  bonds
# .
#  Additionally
# ,
#  mutual
#  funds
#  are
#  managed
#  by
#  professional
#  fund
#  managers
#  who
#  make
#  investment
#  decisions
#  on
#  behalf
#  of
#  the
#  fund
# 's
#  investors
# .
#  This
#  can
#  be
#  beneficial
#  for
#  those
#  who
#  are
#  not
#  confident
#  in
#  their
#  own
#  investment
#  skills
# .
#  It
# 's
#  important
#  to
#  carefully
#  consider
#  your
#  investment
#  goals
# ,
#  risk
#  tolerance
# ,
#  and
#  time
#  horizon
#  before
#  selecting
#  a
# ...
